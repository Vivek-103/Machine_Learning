# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ### Training the Model on whole Dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Training the Polynomial Regression Model on the Whole Dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly , y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Visualisation the Linear Regression Model

# %%
pyplot.scatter(X , y , color = 'red')
pyplot.plot(X,lin_reg.predict(X),color='blue')
pyplot.title("Linear Regression Model Result")
pyplot.xlabel('Position Level')
pyplot.ylabel('Salary')
pyplot.show()

# %% [markdown]
# ### Visualising the Polynomial Regression Result

# %%
pyplot.scatter(X,y,color = 'red')
pyplot.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)),color='blue')
pyplot.title('Polynomial Regression Results')
pyplot.xlabel('Positions Level')
pyplot.ylabel('Salary')
pyplot.show()

# %% [markdown]
# ### Visualising the Polynomoal Regression (but with better resolutions)

# %%
X_grid = np.arange(X.min(), X.max(), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))

pyplot.scatter(X, y, color='red')
pyplot.plot(
    X_grid,
    lin_reg_2.predict(poly_reg.fit_transform(X_grid)),
    color='blue'
)
pyplot.title('Truth or Bluff (Polynomial Regression)')
pyplot.xlabel('Position level')
pyplot.ylabel('Salary')
pyplot.show()

# %% [markdown]
# ### Predicting the Salary with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ### Predicting the Salary with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.4526515])
